# %%
from twnews.wtmf.support_functions import memo_process, dump, load
from twnews.dataset.dataset import Dataset
from twnews.timeit import timeit

texts = load('texts')
P,Q = load('PQ_1_20')
dataset = Dataset(fraction=1, use_dataset_if_exist=True)
news_texts = dataset.news_storage.get_texts()
news = dataset.news_storage.get_news()
tweets = dataset.dataset
tweets_texts = [tweet.text for tweet in dataset.dataset]
# Out:
# 2016-04-08 14:21:27.720196: Start of loading news from /home/avybornov/twnews_data/rss
# 2016-04-08 14:21:27.896981: News successfully loaded

# %%
len(news), len(tweets)
# Out:
# (7084, 1091)

# %%
nt = []

for i in range(len(news_texts)):
    nt.append((news[i], Q[:,i]))

tt = []
for i in range(len(tweets_texts)):
    tt.append((tweets[i], Q[:,i+len(news_texts)]))

# %%
from sklearn.metrics.pairwise import cosine_similarity

    #sorted(sim_list, key=lambda x: x[1])

# %%
from multiprocessing import Pool

def find_topk_sim_news_to_tweet(tweet_pair, news_pairs, k=10):
    tweet, tweet_latent_vector = tweet_pair
    sim_list = [(x[0],cosine_similarity(tweet_latent_vector, x[1])[0][0]) for x in news_pairs]
    sim_list = sorted(sim_list, key=lambda x: x[1], reverse=True)
    #print map(lambda x: x[1], sim_list[:10])
    return map(lambda x: x[0], sim_list[:k])

def f(x):
    t, news_pairs, k = x
    res = find_topk_sim_news_to_tweet(t, news_pairs, k)
    return (t[0], res)

@timeit
def find_topk_sim_news_to_tweets(tweet_pairs, news_pairs, k=10):    
    top = []

    p = Pool(16)
    return p.map(f, [(tweet, news_pairs, k) for tweet in tweet_pairs])
    #return top

# %%
top = find_topk_sim_news_to_tweets(tt[:10],nt, k=10)
# Out:
# 2016-04-08 14:21:36.002501: Function find_topk_sim_news_to_tweets started with time measure
# 2016-04-08 14:21:39.055952: Function find_topk_sim_news_to_tweets finished in 0m3.05304789543s

# %%
def TOPK_t(tweet, top_news, k):
    top_news = top_news[:k]
    for news in top_news:
        for url in tweet.urls:
            if url == news.link:
                return 1
    return 0

def TOPK(tweets, k):
    s = 0
    for tweet, top_news in tweets:
        s += TOPK_t(tweet, top_news, k)
    return s*1.0/len(tweets)


def ATOP(tweets, N):
    s = 0
    for k in range(1,N+1):
        s += TOPK(tweets, k)
    return s*1.0/N

for res in top[:10]:
    tweet, top_news = res
    print tweet, 
    for news in top_news:
        print news.title
    print '-------'
#ATOP(top,10)
    #top_news
#print top[0][1][0].title
# Out:
# Солдаты шиитской организации «Хезболла» нанесли ракетный удар по позициям террористов ИГИЛ* недалеко от ливано-сир…  СМИ: «Хезболла» нанесла ракетный удар по базе ИГИЛ на границе с Сирией
# Глава Македонии: нелегальная миграция угрожает безопасности в регионе
# СМИ: У Пальмиры уничтожены штаб-квартиры ИГИЛ и «Ан-Нусры»
# Гройсман: парламентская коалиция Рады продолжает существовать
# Власти Турции: Теракт в Стамбуле совершил боевик ИГИЛ
# СМИ: Турция планирует расширить штат полиции на 15 тысяч человек
# ООН направила гуманитарную помощь для жителей сирийского Блудана
# Настоящее лицо УПА
# Каир надеется на возобновление авиасообщения с Россией к лету
# Путин: власти должны заниматься вопросами безопасности на дорогах
# Нарышкин выступил за ужесточение наказания за применение допинга
# В аэропорту Ростова открыли представительство МИД РФ
# ЦБ предлагает сделать обязательной продажу электронных полисов ОСАГО
# Романо Проди констатировал "конец сбалансированной Европы"
# -------
# В Госдуме хотят ввести санкции против Хиллари Клинтон
# © AP  Ковалев: РФ вновь поднимет в ПА ОБСЕ вопрос санкциях против депутатов
# Али Хаменеи возлагает на США вину за проблемы Ирана в банковской сфере
# На место крушения Boeing выдвинулась мобильная группировка СКРЦ МЧС
# Сирийский политолог: будущее Сирии во многом зависит от решений России
# СМИ: В Грузии арестованы обвиняемые по делу о скандальных видеозаписях
# Календарь событий 19марта – 20 апреля (Часть 2)
# Календарь событий 19марта – 20 апреля (Часть 1)
# Лидера рязанского отделения ПАРНАСа приговорили к обязательным работам
# Андрей Воробьев попал в топ-15 самых цитируемых блогеров РФ
# Сирийская операция. Итоги
# -------
# В Госдуме хотят ввести санкции против Хиллари Клинтон
# © AP  Ковалев: РФ вновь поднимет в ПА ОБСЕ вопрос санкциях против депутатов
# Али Хаменеи возлагает на США вину за проблемы Ирана в банковской сфере
# На место крушения Boeing выдвинулась мобильная группировка СКРЦ МЧС
# Сирийский политолог: будущее Сирии во многом зависит от решений России
# СМИ: В Грузии арестованы обвиняемые по делу о скандальных видеозаписях
# Календарь событий 19марта – 20 апреля (Часть 2)
# Календарь событий 19марта – 20 апреля (Часть 1)
# Лидера рязанского отделения ПАРНАСа приговорили к обязательным работам
# Андрей Воробьев попал в топ-15 самых цитируемых блогеров РФ
# Сирийская операция. Итоги
# -------
# Основатель "ВКонтакте" шокирован разоблачениями Сноудена  с помощью @rianru Основатель "ВКонтакте" шокирован разоблачениями Сноудена
# Задержанные в Малайзии журналисты телеканала ABC покинули страну
# Погибший на тренировке по хоккею мальчик играл без шлема
# МЭР до 21 марта ждет от банков ответа о участии в приватизации
# В ДНР предлагают обновить границы линии соприкосновения в Донбассе
# ФСБ провела в Псковской области обыски по делу о хищениях
# Во вторник будет избран президент Мьянмы
# В Нигере открылись избирательные участки на II туре выборов президента
# Заседание австралийского парламента продолжается уже 40 часов
# Минфин рассчитывает выйти на бездефицитный бюджет к 2017-2019 годам
# -------
# СМИ: в Госдуме предложили ввести санкции против Хиллари Клинтон  с помощью @rianru Суд рассмотрит вопрос содержания Есипенко по делу о погромах в Манеже
# В Раде зарегистрирован документ о разрыве дипотношений с Россией
# США примут участие в расследовании авиакатастрофы с «боингом»
# Минтруд: крупные работодатели не планируют высвобождать сотрудников
# Директора Союза кинологических организаций подозревают в мошенничестве
# Операция «Сирия»: итоги и значение
# Новак: прогнозировать цены после заморозки нефтедобычи сложно
# Узбекистан с 1 апреля повысит цены на газ более чем на 8%
# Межгосударственные отношения России и Египта
# Новые группы самолётов вылетели из Сирии в Россию
# -------

# %%
import random
k = 10
set_news = set(news)
random_top = []
for tweet in tweets:
    sample = random.sample(set_news, k)
    random_top.append((tweet, sample))

# %%
ATOP(random_top,10)
# Out:
# 0.0009165902841429881
